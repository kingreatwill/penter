# %% [markdown]
# https://numpy.org/doc/stable/reference/routines.char.html

# %%
import numpy as np
c = np.array(['a1b c', '1bca', 'bca1'])

c,np.char.upper(c),np.char.find(c,'ca')
# Out:
# (array(['a1b c', '1bca', 'bca1'], dtype='<U5'),
#  array(['A1B C', '1BCA', 'BCA1'], dtype='<U5'),
#  array([-1,  2,  1]))
